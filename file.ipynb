# %%
# !python scrape_entrackr.py --pages 3 --max-articles 30
# Out:
# ...
# Listing page 1: https://entrackr.com/report/weekly-funding-report
# Listing page 2: https://entrackr.com/report/weekly-funding-report?page=2
# Listing page 3: https://entrackr.com/report/weekly-funding-report?page=3
# Found 30 total, 30 new to fetch this run.
# [1/30] https://entrackr.com/report/weekly-funding-report/funding-and-acquisitions-in-indian-startups-this-week-aug-24-aug-29-12451075
#   -> extracted 7 deal records
# [2/30] https://entrackr.com/report/weekly-funding-report/funding-and-acquisitions-in-indian-startups-this-week-june-22-june-27-12110860
#   -> extracted 8 deal records
# [3/30] https://entrackr.com/report/weekly-funding-report/funding-and-acquisitions-in-indian-startup-this-week-apr-6-apr-11-11714653
#   -> extracted 6 deal records
# [4/30] https://entrackr.com/report/weekly-funding-report/funding-and-acquisitions-in-indian-startup-this-week-mar-30-apr-4-11452029
#   -> extracted 7 deal records
# ...

# %%
# !python scrape_entrackr.py --pages 8 --max-articles 60
# Out:
# ...
# Listing page 1: https://entrackr.com/report/weekly-funding-report
# Listing page 2: https://entrackr.com/report/weekly-funding-report?page=2
# Listing page 3: https://entrackr.com/report/weekly-funding-report?page=3
# Listing page 4: https://entrackr.com/report/weekly-funding-report?page=4
# Listing page 5: https://entrackr.com/report/weekly-funding-report?page=5
# Listing page 6: https://entrackr.com/report/weekly-funding-report?page=6
# Listing page 7: https://entrackr.com/report/weekly-funding-report?page=7
# Listing page 8: https://entrackr.com/report/weekly-funding-report?page=8
# Found 74 total, 44 new to fetch this run.
# [1/44] https://entrackr.com/report/weekly-funding-report/funding-and-acquisitions-in-indian-startup-this-week-sep-22-sep-27-10506787
#   -> extracted 4 deal records
# [2/44] https://entrackr.com/report/weekly-funding-report/funding-and-acquisitions-in-indian-startup-this-week-sep-15-sep-20-10481823
#   -> extracted 3 deal records
# ...

# %%
# !pip install networkx python-louvain
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for python-louvain: filename=python_louvain-0.16-py3-none-any.whl size=9473 sha256=8f505433e8a889a5243730f8c8af4aaa8a9ac68eb4d6688cd16433ce255d6db4
#   Stored in directory: c:\users\pratyush\appdata\local\pip\cache\wheels\ee\52\54\7ecd0f1ebf5f5a8466f70a27ed2b94d20b955376879d6159c5
# Successfully built python-louvain
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\PRATYUSH\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\PRATYUSH\AppData\Roaming\Python\Python313\site-packages)
# ...

# %%
# !python build_graph.py funding_deals_clean.json
# Out:
# Loaded 127 deal records
# Co-investment graph: 150 investors, 105 co-investment edges
# Bipartite graph: 225 total nodes (investors + companies), 174 investment edges
#
# Detected 81 investor communities
#
# Top 10 investors by degree (most active co-investors):
#   Accel: 9 connections, 4 deals
#   Lachy Groom: 6 connections, 2 deals
#   Lightspeed: 6 connections, 3 deals
#   Nexus Venture Partners: 6 connections, 3 deals
#   Peak XV Partners: 6 connections, 9 deals
#   Capital 2B: 4 connections, 1 deals
#   Helena: 4 connections, 1 deals
#   Japan Airlines: 4 connections, 1 deals
#   SMSC: 4 connections, 1 deals
#   TransLink Innovation Fund: 4 connections, 1 deals
#
# Top 10 investors by betweenness (bridge/connector investors):
#   Accel: 0.0063
#   Lightspeed: 0.0049
#   Lachy Groom: 0.0024
#   Nexus Venture Partners: 0.0013
#   Peak XV Partners: 0.0010
#   Bessemer Venture Partners: 0.0005
#   Unicorn India Ventures: 0.0002
#   Ashish Kacholia: 0.0002
#   360 ONE Asset: 0.0001
# ...

# %%
# !python recommend_syndicate.py funding_deals_clean.json --company "Airbound"
# Out:
# Company: Airbound
#   Inferred lead investor: Greenoaks
#   Inferred sector: aerospace_deeptech
#
# Syndicate recommendations for lead investor: Greenoaks (sector: aerospace_deeptech)
# ------------------------------------------------------------------------------
# Investor                           Score  Prior deals  Shared-nbr  Same cluster
# ------------------------------------------------------------------------------
# DoorDash                           0.650            1       0.000          True
# Humba Ventures                     0.650            1       0.000          True
# Lachy Groom                        0.575            1       0.000          True
# Lightspeed                         0.550            1       0.000          True
# Alpha Wave                         0.500            0       0.558          True
# Sharrp Ventures                    0.500            0       0.558          True
# ...
